# %%
# Que1.Explain the significance of Python keywords and provide examples of five keywords.
"""
Ans1. In Python, keywords are reserved words that have a predefined meaning and cannot be used as identifiers 
(such as variable names, function names, or class names). These keywords define the syntax and structure of 
the Python language. They are fundamental to Python syntax and are used to define control flow.

Examples of 5 keywords:
Here we are going to create a single program that will have 5 keywords : "True","Flase","if","elif","and"

"""

# %%
x=True
y=False

if x==True and y==True:
    print("x and y both are True")
elif x==False:
    print("x is false")
elif y==False:
    print("Y is false")
# Out:
# Y is false

# %%
# Que2. Describe the rules for defining identifiers in Python and provide an example.
"""
Ans2: Here are the key rules for defining identifiers in Python:

1. The first character must be a letter (a-z, A-Z) or an underscore (_):
2. After the first character, an identifier can contain letters (a-z, A-Z), digits (0-9), or underscores.
3. Identifiers are case-sensitive: myvar, MyVar, and MYVAR are considered three different identifiers.
4. Identifiers cannot be Python keywords.
5. Identifiers should be meaningful.

# Examples of Valid identifiers
user_name = "Alice"
total_amount = 150
_is_valid = True
MyClass = "ClassA"

Invalid Identifiers:

1st_variable = 100  # Invalid: starts with a digit
def = 20  # Invalid: 'def' is a keyword
my-var = 10  # Invalid: contains a hyphen (non-alphanumeric character)
"""

# %%
# Que3.What are comments in Python, and why are they useful? Provide an example.

"""
Ans3. In Python, comments are used to annotate the code with explanatory text. They are not executed by the Python interpreter, meaning they have no effect on the program's behavior. Comments are purely for human readers and help explain what the code does, why certain decisions were made, or to provide other contextual information.

There are two types of comments in Python:

Single-line comments: These are used for brief explanations. A single-line comment begins with the hash (#) symbol.
Multi-line comments: These are typically used for longer explanations or documentation and are enclosed by triple quotes (''' or """).

"""

# %%
# Examples:

# This is a single-line comment
x = 10  # Assigning 10 to variable x

'''
This is a multi-line comment.
You can use this to write longer explanations or documentation.
'''
y=20
print(x+y)
# Out:
# 30

# %%
"""
Que4. Why is proper indentation important in Python?

Ans4. In Python, indentation is not just for readability — it plays a crucial role in defining the structure and flow of the code. Unlike many other programming languages that 
use braces {} or other delimiters to define blocks of code, Python relies on indentation to indicate the grouping of statements. This is known as off-side rule.

Why is it important?

Proper indentation ensures that Python can interpret which code belongs to which block.
It improves readability and avoids syntax errors like IndentationError.
"""

# %%
"""
Que5. What happens if indentation is incorrect in Python?
Ans5. If indentation is incorrect in Python, it leads to errors because Python relies on indentation to define the structure of the code. Python uses indentation to group 
statements into blocks. Therefore, incorrect indentation can cause Python to misinterpret the structure of the program, resulting in errors or unexpected behavior.

For example:
"""

# %%
def greet(name):
     if name:  # Correct indentation
         print(f"Hello, {name}!")
    else:  # Incorrect indentation
        print("Hello, Stranger!")
# Out:
#   File "<tokenize>", line 4
#     else:  # Incorrect indentation
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
"""
Que6. Differentiate between expression and statement in Python with examples.

An expression is a combination of values, variables, operators, and function calls that Python evaluates to produce a result (usually a value). Expressions return a value and 
can be used wherever Python expects a value.

Key Points about Expressions:
An expression can be a simple value like a number or a variable.
It always evaluates to a result.
It can involve operations, function calls, or logical evaluations.

A statement is a line of code that performs some action. Unlike an expression, a statement doesn't return a value; instead, it carries out an operation or produces side effects, such as changing a variable's value, printing something to the screen, or controlling the flow of the program (e.g., if, while, for, etc.).

Key Points about Statements:
A statement represents an instruction that Python will execute.
It does not return a value like an expression.
Statements typically control the flow of the program or perform actions.
"""

# %%
#Example:

x = 10  # Statement (assignment)
y = x + 5  # Expression (x + 5 evaluates to 15, and assigns it to y)
if y > 10:  # Statement (conditional)
    print("y is greater than 10")  # Statement (action)
# Out:
# y is greater than 10
